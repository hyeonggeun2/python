# %%
import os
import sys
import urllib.request

# %%
client_id = "AFxRpGSu0xgV1JADUczQ"
client_secret = "1s9iiEeScQ"

encText = urllib.parse.quote("성수역 맛집")
url = "https://openapi.naver.com/v1/search/local.json?start=3&display=30&query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 16 Jan 2020 20:39:02 +0900",
# "total": 3787,
# "start": 3,
# "display": 30,
# "items": [
# {
# "title": "권식족발",
# "link": "http://blog.naver.com/20002345/",
# "category": "한식>족발,보쌈",
# "description": "",
# "telephone": "02-465-8516",
# "address": "서울특별시 성동구 성수동2가 300-64",
# "roadAddress": "서울특별시 성동구 아차산로7길 4",
# "mapx": "316632",
# "mapy": "549683"
#
# },
# {
# "title": "어니언 성수",
# "link": "http://www.instagram.com/cafe.onion/",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "02-1644-1941",
# "address": "서울특별시 성동구 성수동2가 277-135",
# "roadAddress": "서울특별시 성동구 아차산로9길 8 어니언",
# "mapx": "316975",
# "mapy": "549596"
#
# },
# {
# "title": "카페온화 성수",
# "link": "http://www.instagram.com/onhwa_cafe",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "02-461-0031",
# "address": "서울특별시 성동구 성수동2가 302-4 1층",
# "roadAddress": "서울특별시 성동구 아차산로 78 1층",
# "mapx": "316470",
# "mapy": "549657"
#
# },
# {
# "title": "카페봇",
# "link": "https://www.instagram.com/cafe.bot/",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "02-499-9219",
# "address": "서울특별시 성동구 성수동2가 277-135",
# "roadAddress": "서울특별시 성동구 아차산로9길 8",
# "mapx": "316990",
# "mapy": "549577"
#
# },
# {
# "title": "성수족발",
# "link": "http://blog.naver.com/ssjb1983",
# "category": "한식>족발,보쌈",
# "description": "",
# "telephone": "02-464-0425",
# "address": "서울특별시 성동구 성수동2가 289-273 동진빌딩 1F",
# "roadAddress": "서울특별시 성동구 아차산로7길 7 동진빌딩 1층 성수족발",
# "mapx": "316637",
# "mapy": "549742"
#
# },
# {
# "title": "브루잉 세레모니",
# "link": "https://www.instagram.com/brewingceremony/",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 315-27 1층",
# "roadAddress": "서울특별시 성동구 연무장5가길 22-1 1층",
# "mapx": "316702",
# "mapy": "549430"
#
# },
# {
# "title": "자그마치",
# "link": "https://www.instagram.com/zagmachi",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 317-12",
# "roadAddress": "서울특별시 성동구 성수이로 88",
# "mapx": "316841",
# "mapy": "549363"
#
# },
# {
# "title": "해만<b>식당</b>",
# "link": "http://www.instagram.com/haemansikdang/",
# "category": "일식>덮밥",
# "description": "",
# "telephone": "02-6053-0309",
# "address": "서울특별시 성동구 성수동2가 315-17",
# "roadAddress": "서울특별시 성동구 연무장9길 10",
# "mapx": "316781",
# "mapy": "549407"
#
# },
# {
# "title": "카페 포제",
# "link": "http://www.instagram.com/cafe_poze",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 315-41",
# "roadAddress": "서울특별시 성동구 연무장9길 7",
# "mapx": "316755",
# "mapy": "549395"
#
# },
# {
# "title": "마를리",
# "link": "http://www.instagram.com/marly.official_",
# "category": "카페,디저트>케이크전문",
# "description": "",
# "telephone": "02-467-0303",
# "address": "서울특별시 성동구 성수동2가 315-55 1층",
# "roadAddress": "서울특별시 성동구 연무장길 47 홍원빌딩",
# "mapx": "316671",
# "mapy": "549384"
#
# },
# {
# "title": "스피닝울프 성수",
# "link": "https://spinningwolf.modoo.at",
# "category": "술집>바(BAR)",
# "description": "",
# "telephone": "02-465-0884",
# "address": "서울특별시 성동구 성수동2가 314-12",
# "roadAddress": "서울특별시 성동구 연무장7길 11 11층",
# "mapx": "316638",
# "mapy": "549489"
#
# },
# {
# "title": "도렐 육지3호점",
# "link": "http://www.instagram.com/dorrell_coffee",
# "category": "카페,디저트>카페",
# "description": "",
# "telephone": "02-516-3675",
# "address": "서울특별시 성동구 성수동2가 314-12",
# "roadAddress": "서울특별시 성동구 연무장7길 11 1층 도렐",
# "mapx": "316638",
# "mapy": "549490"
#
# },
# {
# "title": "Arco",
# "link": "",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "02-468-2122",
# "address": "서울특별시 성동구 성수동2가 314-2",
# "roadAddress": "서울특별시 성동구 연무장5길 20",
# "mapx": "316554",
# "mapy": "549612"
#
# },
# {
# "title": "핑거팁스",
# "link": "https://www.instagram.com/fingertipsburger/",
# "category": "음식점>햄버거",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 315-36",
# "roadAddress": "서울특별시 성동구 연무장7가길 5-1 1층",
# "mapx": "316699",
# "mapy": "549418"
#
# },
# {
# "title": "글로우",
# "link": "http://www.instagram.com/glow__coffee",
# "category": "카페,디저트>카페",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 277-24 1층 글로우",
# "roadAddress": "서울특별시 성동구 아차산로9길 20 1층 글로우",
# "mapx": "317018",
# "mapy": "549731"
#
# },
# {
# "title": "잇샐러드",
# "link": "http://itsalad.co.kr/index.html#01",
# "category": "도시락,컵밥>다이어트,샐러드",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 300-8 1층",
# "roadAddress": "서울특별시 성동구 성수일로8길 28 1층",
# "mapx": "316559",
# "mapy": "549724"
#
# },
# {
# "title": "텐동<b>식당</b>",
# "link": "http://www.instagram.com/tendongsikdang",
# "category": "일식>덮밥",
# "description": "",
# "telephone": "02-6339-0309",
# "address": "서울특별시 성동구 성수동2가 315-29",
# "roadAddress": "서울특별시 성동구 연무장5가길 20-1 1층",
# "mapx": "316682",
# "mapy": "549439"
#
# },
# {
# "title": "그리드채플린",
# "link": "http://instagram.com/gridchaplin",
# "category": "술집>맥주,호프",
# "description": "",
# "telephone": "02-6463-6200",
# "address": "서울특별시 성동구 성수동2가 289-21",
# "roadAddress": "서울특별시 성동구 아차산로7길 15-1 효정빌딩",
# "mapx": "316646",
# "mapy": "549788"
#
# },
# {
# "title": "토라<b>식당</b>",
# "link": "",
# "category": "일식>일식당",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 315-48",
# "roadAddress": "서울특별시 성동구 연무장7가길 6-1 지하 토라식당",
# "mapx": "316695",
# "mapy": "549398"
#
# },
# {
# "title": "닭칼 성수본점",
# "link": "http://b808.callbaro.com/",
# "category": "한식>닭요리",
# "description": "",
# "telephone": "02-461-1312",
# "address": "서울특별시 성동구 성수동2가 301-4",
# "roadAddress": "서울특별시 성동구 연무장3길 21",
# "mapx": "316418",
# "mapy": "549690"
#
# },
# {
# "title": "사계",
# "link": "http://www.instagram.com/seasons_kr",
# "category": "술집>요리주점",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 273-51",
# "roadAddress": "서울특별시 성동구 연무장13길 19",
# "mapx": "317013",
# "mapy": "549425"
#
# },
# {
# "title": "로우키",
# "link": "",
# "category": "음식점>카페,디저트",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 302-16",
# "roadAddress": "서울특별시 성동구 연무장3길 6",
# "mapx": "316389",
# "mapy": "549537"
#
# },
# {
# "title": "내풀로",
# "link": "http://www.instagram.com/naepulo",
# "category": "음식점>양식",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 315-35",
# "roadAddress": "서울특별시 성동구 연무장7가길 5",
# "mapx": "316687",
# "mapy": "549426"
#
# },
# {
# "title": "와하카",
# "link": "http://www.instagram.com/oaxaca_seongsu",
# "category": "음식점>멕시코,남미음식",
# "description": "",
# "telephone": "02-462-7292",
# "address": "서울특별시 성동구 성수동2가 299-225",
# "roadAddress": "서울특별시 성동구 성수일로12길 29",
# "mapx": "316641",
# "mapy": "549944"
#
# },
# {
# "title": "대박낙소 성수점",
# "link": "",
# "category": "육류,고기요리>소고기구이",
# "description": "",
# "telephone": "02-3499-4496",
# "address": "서울특별시 성동구 성수동2가 284-62 상가동 1층",
# "roadAddress": "서울특별시 성동구 성수일로10길 26 상가동 1층",
# "mapx": "316512",
# "mapy": "549800"
#
# },
# {
# "title": "스미토라",
# "link": "http://www.instagram.com/sumitora.316-19",
# "category": "일식>일식당",
# "description": "",
# "telephone": "02-6406-1119",
# "address": "서울특별시 성동구 성수동2가 316-19 1층",
# "roadAddress": "서울특별시 성동구 연무장길 29-9 1층",
# "mapx": "316494",
# "mapy": "549451"
#
# },
# {
# "title": "레몬그라스",
# "link": "http://www.instagram.com/lemongrass.seongsu",
# "category": "음식점>태국음식",
# "description": "",
# "telephone": "",
# "address": "서울특별시 성동구 성수동2가 316-22 1층",
# "roadAddress": "서울특별시 성동구 연무장길 41-26 1층",
# "mapx": "316626",
# "mapy": "549448"
#
# },
# {
# "title": "프랑스포차",
# "link": "https://francepocha.modoo.at",
# "category": "술집>요리주점",
# "description": "",
# "telephone": "02-3144-9191",
# "address": "서울특별시 성동구 성수동2가 315-30",
# "roadAddress": "서울특별시 성동구 연무장5가길 20",
# "mapx": "316671",
# "mapy": "549443"
#
# },
# {
# "title": "쓰리오브어스",
# "link": "http://instagram.com/3_of_us_",
# "category": "술집>바(BAR)",
# "description": "",
# "telephone": "02-461-1233",
# "address": "서울특별시 성동구 성수동2가 316-24 1층",
# "roadAddress": "서울특별시 성동구 연무장길 41-18 1층",
# "mapx": "316616",
# "mapy": "549428"
#
# },
# {
# "title": "풍조미역",
# "link": "",
# "category": "음식점>한식",
# "description": "",
# "telephone": "02-466-6665",
# "address": "서울특별시 성동구 성수동2가 300-39",
# "roadAddress": "서울특별시 성동구 성수일로8길 60 1층",
# "mapx": "316849",
# "mapy": "549602"
#
# }
# ]
# }
